# %% [markdown]
# # **Client COD Study**

# %% [markdown]
# ## Objectives
#
# * To understand the COD level fluctuations throughout the different seasons based on other variables to see which show the best correlation.
#
# ## Inputs
#
# * outputs/datasets/collection/data-melborne_f.csv
#
# ## Outputs
#
# *  generrate code that answers business requirement 1 and can build Streamlit App

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/Nod-to-the-COD/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspaces/Nod-to-the-COD'

# %% [markdown]
# # Load Data

# %% [markdown]
# I have already dropped the index column and the year, month, and day columns, as I have creatded a timestamp column to replace these 3 columns. This helps with time-based functionality as I am interested in time series data.

# %% [markdown]
# Load data sheet

# %%
import pandas as pd
df = pd.read_csv(f"outputs/datasets/collection/Data-Melbourns_F_fixed.csv")
df.head()
# Out:
#    Average Outflow  Average Inflow  Energy Consumption  Ammonia  \
# 0            2.941           2.589            175856.0     27.0
# 1            2.936           2.961            181624.0     25.0
# 2            2.928           3.225            202016.0     42.0
# 3            2.928           3.354            207547.0     36.0
# 4            2.917           3.794            202824.0     46.0
#
#    Biological Oxygen Demand  Chemical Oxygen Demand  Total Nitrogen  \
# 0                     365.0                   730.0          60.378
# 1                     370.0                   740.0          60.026
# 2                     418.0                   836.0          64.522
# 3                     430.0                   850.0          63.000
# 4                     508.0                  1016.0          65.590
#
#    Average Temperature  Maximum temperature  Minimum temperature  \
# 0                 19.3                 25.1                 12.6
# ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Lets explore the data using Pandas profiling

# %%
from pandas_profiling import ProfileReport
pandas_report = ProfileReport(df=df, minimal=True)
pandas_report.to_notebook_iframe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# /tmp/ipykernel_905/962869596.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## Correlation Study

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %% [markdown]
# ---

# %%
corr_spearman = df.corr(method='spearman')['Chemical Oxygen Demand'].sort_values(key=abs, ascending=False)[1:].head(10)
corr_spearman
# Out:
# Total Nitrogen              0.766683
# Biological Oxygen Demand    0.456210
# Ammonia                     0.296885
# year                        0.276204
# date                        0.268945
# Average humidity           -0.165520
# Total rainfall             -0.159646
# Maximum temperature         0.114882
# Average Temperature         0.102299
# Minimum temperature         0.069284
# Name: Chemical Oxygen Demand, dtype: float64

# %%
corr_pearson = df.corr(method='pearson')['Chemical Oxygen Demand'].sort_values(key=abs, ascending=False)[1:].head(10)
corr_pearson
# Out:
# Total Nitrogen              0.681225
# Biological Oxygen Demand    0.524189
# Ammonia                     0.284552
# year                        0.231927
# date                        0.227455
# Average humidity           -0.152655
# Maximum temperature         0.090018
# Average Temperature         0.083946
# Total rainfall             -0.055335
# Minimum temperature         0.052716
# Name: Chemical Oxygen Demand, dtype: float64

# %%
top_n = 5
set(corr_pearson[:top_n].index.to_list() + corr_spearman[:top_n].index.to_list())
# Out:
# {'Ammonia', 'Biological Oxygen Demand', 'Total Nitrogen', 'date', 'year'}

# %% [markdown]
# We can see from the above data that there are 2 variables that show the most correlation to the COD level.
# - Total Nitrogen, TN
# - Biological Oxygen Demand, BOD

# %% [markdown]
# Now we want to run a heatmap analysis

# %%
# %matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# The above heatmap is far too messy with too much information. Below I have filtered out columns and we can now see the correlation between the selected relevant features and the target variable, Chemical Oxygen Demand, COD.
# I also added code to mask the heatmap plot so its easier to look at without hte repeated information.

# %%
import numpy as np

# Filter to only relevant columns
relevant_cols = [
    'Ammonia', 'Biological Oxygen Demand', 'Chemical Oxygen Demand',
    'Total Nitrogen'
]

filtered_df = df[relevant_cols]

# Calculate correlation matrix
corr = filtered_df.corr()

# Create mask for upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Plot heatmap with mask applied
plt.figure(figsize=(12, 10))
sns.heatmap(
    corr,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=0.5,
    mask=mask
)

plt.title('Correlation Heatmap (Filtered Features)', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In case you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create here your folder
  # os.makedirs(name='')
except Exception as e:
  print(e)
